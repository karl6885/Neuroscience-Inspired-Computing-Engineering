# %%
import numpy as np
import pandas as pd
import midi
import os

# %%
pattern = midi.read_midifile("./train/mz_311_1.mid")
print (pattern)
# Out:
# midi.Pattern(format=1, resolution=480, tracks=\
# [midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Klaviersonate Nr. 8 KV 311 1. Satz', data=[75, 108, 97, 118, 105, 101, 114, 115, 111, 110, 97, 116, 101, 32, 78, 114, 46, 32, 56, 32, 75, 86, 32, 51, 49, 49, 32, 49, 46, 32, 83, 97, 116, 122]),
#    midi.CopyrightMetaEvent(tick=0, text='Copyright © 2006 von Bernd Krüger. ', data=[67, 111, 112, 121, 114, 105, 103, 104, 116, 32, 169, 32, 50, 48, 48, 54, 32, 118, 111, 110, 32, 66, 101, 114, 110, 100, 32, 75, 114, 252, 103, 101, 114, 46, 32]),
#    midi.TextMetaEvent(tick=0, text='Wolfgang Amadeus Mozart', data=[87, 111, 108, 102, 103, 97, 110, 103, 32, 65, 109, 97, 100, 101, 117, 115, 32, 77, 111, 122, 97, 114, 116]),
#    midi.TextMetaEvent(tick=0, text='Herausgegeben am  1.7.2006\n', data=[72, 101, 114, 97, 117, 115, 103, 101, 103, 101, 98, 101, 110, 32, 97, 109, 32, 32, 49, 46, 55, 46, 50, 48, 48, 54, 10]),
#    midi.TextMetaEvent(tick=0, text='Update am 5.6.2013\n', data=[85, 112, 100, 97, 116, 101, 32, 97, 109, 32, 53, 46, 54, 46, 50, 48, 49, 51, 10]),
#    midi.TextMetaEvent(tick=0, text='Dauer:  4:19 Minuten\n', data=[68, 97, 117, 101, 114, 58, 32, 32, 52, 58, 49, 57, 32, 77, 105, 110, 117, 116, 101, 110, 10]),
#    midi.TimeSignatureEvent(tick=0, data=[4, 2, 24, 8]),
#    midi.KeySignatureEvent(tick=0, data=[2, 0]),
#    midi.SetTempoEvent(tick=0, data=[6, 116, 130]),
#    midi.MarkerEvent(tick=0, text='Teil 1', data=[84, 101, 105, 108, 32, 49]),
#    midi.SetTempoEvent(tick=960, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=720, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=1680, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=480, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=720, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=1680, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=570, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=60, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=30, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=30, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=30, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=30, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=30, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=30, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=30, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=30, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=120, data=[5, 253, 145]),
#    midi.SetTempoEvent(tick=90, data=[6, 7, 171]),
#    midi.SetTempoEvent(tick=90, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=1200, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=240, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=60, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=90, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=60, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=90, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=60, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=570, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=60, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=30, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=30, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=30, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=30, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=30, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=30, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=30, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=30, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=120, data=[5, 253, 145]),
#    midi.SetTempoEvent(tick=90, data=[6, 7, 171]),
#    midi.SetTempoEvent(tick=90, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=1200, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=240, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=60, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=90, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=60, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=90, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=60, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=89, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=180, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=150, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=150, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=180, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=150, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=90, data=[6, 7, 171]),
#    midi.SetTempoEvent(tick=150, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=150, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=150, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=150, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=150, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=150, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=90, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=300, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=300, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=300, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=330, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=300, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=300, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=61, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=360, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=120, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=840, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=720, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=720, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=360, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=360, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=120, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[9, 43, 190]),
#    midi.SetTempoEvent(tick=360, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=120, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=120, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=120, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=840, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=480, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=1200, data=[6, 126, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 174, 196]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=840, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=2160, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=240, data=[6, 91, 155]),
#    midi.SetTempoEvent(tick=240, data=[6, 138, 27]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 69, 79]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=720, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=720, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=480, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=525, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=30, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=30, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 255, 114]),
#    midi.SetTempoEvent(tick=195, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[8, 66, 186]),
#    midi.SetTempoEvent(tick=120, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=720, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=480, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=525, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=30, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=30, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 255, 114]),
#    midi.SetTempoEvent(tick=195, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=720, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=11, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=589, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=480, data=[7, 163, 229]),
#    midi.SetTempoEvent(tick=1440, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[7, 55, 242]),
#    midi.SetTempoEvent(tick=240, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=240, data=[7, 116, 32]),
#    midi.SetTempoEvent(tick=240, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[7, 231, 113]),
#    midi.SetTempoEvent(tick=240, data=[7, 147, 181]),
#    midi.SetTempoEvent(tick=240, data=[8, 187, 195]),
#    midi.SetTempoEvent(tick=240, data=[8, 85, 251]),
#    midi.SetTempoEvent(tick=480, data=[9, 141, 189]),
#    midi.SetTempoEvent(tick=480, data=[8, 187, 195]),
#    midi.SetTempoEvent(tick=960, data=[6, 116, 130]),
#    midi.MarkerEvent(tick=0, text='Teil 1 Wiederholung', data=[84, 101, 105, 108, 32, 49, 32, 87, 105, 101, 100, 101, 114, 104, 111, 108, 117, 110, 103]),
#    midi.SetTempoEvent(tick=960, data=[6, 69, 79]),
#    midi.SetTempoEvent(tick=480, data=[6, 47, 157]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=1680, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=480, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=720, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=1680, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=570, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=60, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=30, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=30, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=30, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=30, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=30, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=30, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=30, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=30, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=120, data=[5, 253, 145]),
#    midi.SetTempoEvent(tick=90, data=[6, 7, 171]),
#    midi.SetTempoEvent(tick=90, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=1200, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=240, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=60, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=90, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=60, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=90, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=60, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=570, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=60, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=30, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=30, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=30, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=30, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=30, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=30, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=30, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=30, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=120, data=[5, 253, 145]),
#    midi.SetTempoEvent(tick=90, data=[6, 7, 171]),
#    midi.SetTempoEvent(tick=90, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=1200, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=240, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=90, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=60, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=90, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=60, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=90, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=60, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=89, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=180, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=150, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=150, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=180, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=150, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=90, data=[6, 7, 171]),
#    midi.SetTempoEvent(tick=150, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=150, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=150, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=47, data=[6, 16, 39]),
#    midi.SetTempoEvent(tick=80, data=[6, 26, 128]),
#    midi.SetTempoEvent(tick=40, data=[6, 36, 253]),
#    midi.SetTempoEvent(tick=40, data=[6, 47, 157]),
#    midi.SetTempoEvent(tick=40, data=[6, 58, 99]),
#    midi.SetTempoEvent(tick=80, data=[6, 69, 79]),
#    midi.SetTempoEvent(tick=40, data=[6, 80, 97]),
#    midi.SetTempoEvent(tick=40, data=[6, 91, 155]),
#    midi.SetTempoEvent(tick=40, data=[6, 102, 252]),
#    midi.SetTempoEvent(tick=3, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=90, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=300, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=300, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=300, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=330, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=300, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=300, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=61, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=360, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=120, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=840, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=720, data=[6, 150, 39]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=720, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=360, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=360, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=120, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[9, 20, 117]),
#    midi.SetTempoEvent(tick=360, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=120, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=120, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=120, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=840, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=480, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=1440, data=[6, 174, 196]),
#    midi.SetTempoEvent(tick=240, data=[6, 253, 31]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=840, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=2160, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=240, data=[6, 102, 252]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=240, data=[6, 102, 252]),
#    midi.SetTempoEvent(tick=240, data=[6, 150, 39]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=240, data=[6, 114, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 150, 39]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 91, 155]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=720, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=720, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=480, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=525, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=30, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=30, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 255, 114]),
#    midi.SetTempoEvent(tick=195, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[8, 66, 186]),
#    midi.SetTempoEvent(tick=120, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=720, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=480, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=525, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=30, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=30, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 255, 114]),
#    midi.SetTempoEvent(tick=195, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=720, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=11, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=589, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=480, data=[7, 163, 229]),
#    midi.SetTempoEvent(tick=1440, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[7, 55, 242]),
#    midi.SetTempoEvent(tick=240, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=240, data=[7, 116, 32]),
#    midi.SetTempoEvent(tick=240, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[7, 231, 113]),
#    midi.SetTempoEvent(tick=240, data=[7, 147, 181]),
#    midi.SetTempoEvent(tick=240, data=[8, 187, 195]),
#    midi.SetTempoEvent(tick=240, data=[8, 85, 251]),
#    midi.SetTempoEvent(tick=480, data=[9, 141, 189]),
#    midi.SetTempoEvent(tick=480, data=[8, 187, 195]),
#    midi.SetTempoEvent(tick=960, data=[6, 93, 135]),
#    midi.MarkerEvent(tick=0, text='Teil 2', data=[84, 101, 105, 108, 32, 50]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=240, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=120, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=215, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=300, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=180, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=60, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=60, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=60, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=60, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=60, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=30, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=90, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=10, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=75, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=960, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=5, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=180, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=180, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=180, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=150, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=10, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=180, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=75, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=960, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[7, 27, 66]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=240, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=240, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[7, 85, 142]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[7, 55, 242]),
#    midi.SetTempoEvent(tick=240, data=[7, 163, 229]),
#    midi.SetTempoEvent(tick=480, data=[8, 85, 251]),
#    midi.SetTempoEvent(tick=480, data=[7, 163, 229]),
#    midi.SetTempoEvent(tick=3600, data=[8, 47, 209]),
#    midi.SetTempoEvent(tick=1680, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=720, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=480, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=525, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=30, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=30, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 255, 114]),
#    midi.SetTempoEvent(tick=195, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[8, 66, 186]),
#    midi.SetTempoEvent(tick=120, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 213, 17]),
#    midi.SetTempoEvent(tick=240, data=[6, 114, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 126, 60]),
#    midi.SetTempoEvent(tick=480, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=480, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=525, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=30, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=30, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 255, 114]),
#    midi.SetTempoEvent(tick=195, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=720, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=600, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=360, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=720, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 114, 135]),
#    midi.SetTempoEvent(tick=360, data=[6, 187, 88]),
#    midi.SetTempoEvent(tick=360, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=720, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=600, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=360, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=720, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=600, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=720, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=600, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=360, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=480, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=120, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=120, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=480, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=480, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=240, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=237, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=3, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=645, data=[6, 17, 231]),
#    midi.SetTempoEvent(tick=60, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=30, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=30, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=30, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=30, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=30, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=30, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=30, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=30, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=30, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=30, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=60, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=14, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=300, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=300, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=330, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=300, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=300, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=61, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=360, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=120, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=840, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=720, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=720, data=[6, 93, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=360, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=120, data=[6, 28, 70]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=360, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=120, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[7, 228, 121]),
#    midi.SetTempoEvent(tick=360, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=120, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=120, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=120, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=840, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=480, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 38, 201]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=240, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=960, data=[6, 213, 17]),
#    midi.SetTempoEvent(tick=240, data=[6, 126, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 138, 27]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 174, 196]),
#    midi.SetTempoEvent(tick=240, data=[6, 91, 155]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=840, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 49, 112]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=960, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=240, data=[6, 82, 71]),
#    midi.SetTempoEvent(tick=240, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=840, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=120, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=2160, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 150, 39]),
#    midi.SetTempoEvent(tick=240, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 126, 60]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 114, 135]),
#    midi.SetTempoEvent(tick=240, data=[6, 104, 240]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=240, data=[6, 71, 46]),
#    midi.SetTempoEvent(tick=480, data=[6, 138, 27]),
#    midi.SetTempoEvent(tick=240, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 60, 60]),
#    midi.SetTempoEvent(tick=480, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=720, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=720, data=[7, 13, 63]),
#    midi.SetTempoEvent(tick=240, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=480, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=240, data=[6, 128, 62]),
#    midi.SetTempoEvent(tick=525, data=[6, 241, 220]),
#    midi.SetTempoEvent(tick=30, data=[6, 228, 121]),
#    midi.SetTempoEvent(tick=30, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=30, data=[6, 202, 77]),
#    midi.SetTempoEvent(tick=30, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=30, data=[6, 176, 228]),
#    midi.SetTempoEvent(tick=30, data=[6, 164, 119]),
#    midi.SetTempoEvent(tick=30, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=30, data=[6, 255, 114]),
#    midi.SetTempoEvent(tick=195, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=240, data=[6, 189, 129]),
#    midi.SetTempoEvent(tick=120, data=[8, 66, 186]),
#    midi.SetTempoEvent(tick=120, data=[6, 116, 130]),
#    midi.SetTempoEvent(tick=480, data=[6, 140, 36]),
#    midi.SetTempoEvent(tick=480, data=[6, 215, 74]),
#    midi.SetTempoEvent(tick=480, data=[6, 152, 55]),
#    midi.SetTempoEvent(tick=360, data=[7, 70, 162]),
#    midi.SetTempoEvent(tick=120, data=[6, 140, 36]),
# ...
#    midi.ControlChangeEvent(tick=394, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=71, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=430, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=65, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=394, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=76, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=176, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=240, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=243, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=237, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=240, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=268, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=213, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=227, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=990, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=930, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=973, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1027, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=890, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1487, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=435, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=499, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=231, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=48, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=190, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=191, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=47, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=182, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=537, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=435, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=44, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=446, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=69, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=409, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=420, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=99, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=388, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=113, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=372, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=499, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=231, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=48, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=190, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=191, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=47, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=182, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=537, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=435, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=44, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=446, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=69, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=409, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=420, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1920, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1920, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1920, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1920, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1920, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=11584, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=425, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=97, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=387, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=86, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=396, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=63, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=413, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1006, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=317, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=607, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=276, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=766, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=147, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=758, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=207, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1707, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=205, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=765, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=201, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=776, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=903, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=948, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=253, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=252, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=218, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=322, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=198, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=720, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=236, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=212, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=222, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=290, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=207, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=779, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=184, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=252, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=218, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=322, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=198, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=826, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=846, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=925, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1920, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=6297, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=435, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=499, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=231, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=48, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=190, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=191, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=47, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=182, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=537, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=435, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=44, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=446, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=69, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=409, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=420, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=537, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=435, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=499, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=231, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=48, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=190, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=191, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=47, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=182, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=537, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=435, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=115, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=122, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=346, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=33, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=449, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=44, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=446, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=69, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=409, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=50, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=420, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=127, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=325, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=3388, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=960, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=4800, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=960, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=1956, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=924, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=127, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=845, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=101, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=847, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=3840, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=75, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=662, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=234, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=75, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=662, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=212, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=195, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=365, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=195, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=308, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=229, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=628, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=252, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=240, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=243, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=237, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=240, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=268, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=213, channel=0, data=[64, 0]),
#    midi.ControlChangeEvent(tick=227, channel=0, data=[64, 127]),
#    midi.ControlChangeEvent(tick=990, channel=0, data=[64, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Mozart: Sonate KV 311', data=[77, 111, 122, 97, 114, 116, 58, 32, 83, 111, 110, 97, 116, 101, 32, 75, 86, 32, 51, 49, 49]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Copyright © 2006 by Bernd Krüger', data=[67, 111, 112, 121, 114, 105, 103, 104, 116, 32, 169, 32, 50, 48, 48, 54, 32, 98, 121, 32, 66, 101, 114, 110, 100, 32, 75, 114, 252, 103, 101, 114]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='http://www.piano-midi.de', data=[104, 116, 116, 112, 58, 47, 47, 119, 119, 119, 46, 112, 105, 97, 110, 111, 45, 109, 105, 100, 105, 46, 100, 101]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Edition: 2013-06-05', data=[69, 100, 105, 116, 105, 111, 110, 58, 32, 50, 48, 49, 51, 45, 48, 54, 45, 48, 53]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Spur 8', data=[83, 112, 117, 114, 32, 56]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Spur 9', data=[83, 112, 117, 114, 32, 57]),
#    midi.EndOfTrackEvent(tick=0, data=[])])])

# %%
# read midi file
def read_midi(filedir):
    result=[]
    for filename in os.listdir(filedir):
        filepath=filedir+"/"+filename
        pattern = midi.read_midifile(filepath)
        result.append(pattern)
    return result

# %%
midi_list=read_midi("./train")

# %% [markdown]
# # Let's make some music

# %%
midi_list[0][1]
# Out:
# midi.Track(\
#   [midi.TrackNameEvent(tick=0, text='Piano right', data=[80, 105, 97, 110, 111, 32, 114, 105, 103, 104, 116]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[0]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[7, 100]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[10, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 73]),
#    midi.TextMetaEvent(tick=0, text='bdca426d104a26ac9dcb070447587523', data=[98, 100, 99, 97, 52, 50, 54, 100, 49, 48, 52, 97, 50, 54, 97, 99, 57, 100, 99, 98, 48, 55, 48, 52, 52, 55, 53, 56, 55, 53, 50, 51]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[91, 127]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 65]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 62]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=468, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[83, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[85, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[86, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 49]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[79, 46]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[77, 54]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[77, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 65]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 62]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=468, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[83, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[85, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[86, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[69, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[78, 47]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[79, 43]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[78, 48]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[79, 43]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=71, channel=0, data=[78, 48]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=71, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[78, 48]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=73, channel=0, data=[76, 48]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=113, channel=0, data=[74, 44]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 50]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[69, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=840, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[69, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[79, 47]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[81, 43]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[79, 48]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[81, 43]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=71, channel=0, data=[79, 48]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=71, channel=0, data=[81, 44]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[79, 48]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[81, 44]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=72, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=73, channel=0, data=[78, 48]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=113, channel=0, data=[76, 44]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 50]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[69, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[78, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=840, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 48]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 49]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 50]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 51]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[83, 52]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[85, 53]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[86, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[85, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[83, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 49]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 51]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 48]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 45]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[75, 43]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 45]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 47]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 49]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 51]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[83, 53]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 53]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 51]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 49]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 48]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 46]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[71, 44]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 50]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 42]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 42]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[69, 40]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 47]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 46]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 46]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 46]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 47]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 48]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 48]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 57]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 44]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 44]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[69, 44]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 57]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[79, 65]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 69]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 56]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[74, 59]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 79]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 74]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 77]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 77]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 69]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 84]),
#    midi.NoteOnEvent(tick=90, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=150, channel=0, data=[81, 74]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=90, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=150, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 74]),
#    midi.NoteOnEvent(tick=90, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=150, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 74]),
#    midi.NoteOnEvent(tick=90, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=150, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 74]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=420, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 41]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 40]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 40]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 40]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 40]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 46]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 48]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 40]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 48]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 44]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[71, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[72, 50]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[72, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 46]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[76, 42]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 51]),
#    midi.NoteOnEvent(tick=720, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 43]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 40]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 37]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 37]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 37]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 46]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 48]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 42]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 40]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 37]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 37]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 37]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 45]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 45]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 45]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 45]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 41]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 45]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 43]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 39]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 43]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 40]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 43]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 40]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 40]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 46]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 43]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 52]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 62]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 49]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 52]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 49]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 43]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 52]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 62]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 49]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 52]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 49]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 41]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[81, 57]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[45, 57]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[45, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[45, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[45, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[40, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[40, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[45, 60]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[45, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 47]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 46]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 50]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 45]),
#    midi.NoteOnEvent(tick=40, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=40, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[76, 45]),
#    midi.NoteOnEvent(tick=39, channel=0, data=[78, 50]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=119, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 50]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 59]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 68]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 53]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 63]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 55]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 49]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 56]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 56]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 48]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 48]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 66]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 47]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 46]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 50]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 45]),
#    midi.NoteOnEvent(tick=40, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=40, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[76, 45]),
#    midi.NoteOnEvent(tick=39, channel=0, data=[78, 50]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=119, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 47]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 50]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 50]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 59]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 68]),
#    midi.NoteOnEvent(tick=360, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 53]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 63]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 55]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 49]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 56]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 56]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 48]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 48]),
#    midi.NoteOnEvent(tick=80, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 75]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[80, 75]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[81, 75]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 64]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=720, channel=0, data=[66, 39]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 36]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 43]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 47]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 39]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[64, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[62, 35]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 42]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[62, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 47]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[62, 39]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[61, 34]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 41]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[61, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 39]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[61, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 41]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[59, 34]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 45]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[59, 37]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[68, 54]),
#    midi.NoteOnEvent(tick=960, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[59, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[61, 35]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 42]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[61, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 73]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[91, 127]),
#    midi.TextMetaEvent(tick=0, text='bdca426d104a26ac9dcb070447587523', data=[98, 100, 99, 97, 52, 50, 54, 100, 49, 48, 52, 97, 50, 54, 97, 99, 57, 100, 99, 98, 48, 55, 48, 52, 52, 55, 53, 56, 55, 53, 50, 51]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 65]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 62]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=468, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[83, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[85, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[86, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 49]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[79, 46]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[77, 54]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[77, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 65]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 62]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=468, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[83, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[85, 45]),
# ...
#    midi.TextMetaEvent(tick=0, text='bdca426d104a26ac9dcb070447587523', data=[98, 100, 99, 97, 52, 50, 54, 100, 49, 48, 52, 97, 50, 54, 97, 99, 57, 100, 99, 98, 48, 55, 48, 52, 52, 55, 53, 56, 55, 53, 50, 51]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 62]),
#    midi.ControlChangeEvent(tick=0, channel=0, data=[91, 127]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 65]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 62]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=468, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[83, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[85, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[86, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 49]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[79, 46]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[77, 54]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[77, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[76, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 65]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[78, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=108, channel=0, data=[81, 62]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=468, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[83, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[85, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[86, 45]),
#    midi.NoteOnEvent(tick=60, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=180, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 45]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 44]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 45]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 46]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 48]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 49]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 53]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[86, 54]),
#    midi.NoteOnEvent(tick=110, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[86, 58]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 49]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[79, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 59]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 59]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 54]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 53]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 53]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 55]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 56]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 56]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 57]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[86, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[88, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[88, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[86, 55]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 55]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[86, 55]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 63]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 61]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 50]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 51]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 57]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 53]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 56]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 54]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 58]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[81, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 66]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 59]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 75]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[85, 75]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 64]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[86, 75]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 64]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=720, channel=0, data=[79, 47]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 39]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 36]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 43]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 39]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[78, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 42]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[67, 35]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 47]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[67, 39]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[67, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 41]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 34]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 39]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 47]),
#    midi.NoteOnEvent(tick=240, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 34]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 41]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 0]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 45]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 54]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[64, 37]),
#    midi.NoteOnEvent(tick=960, channel=0, data=[64, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[67, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 35]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[74, 42]),
#    midi.NoteOnEvent(tick=480, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[66, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])])

# %%
def get_note_event(midi_file):
    note_event=[]
    
    track_total=len(midi_file)
    for track_num in range(track_total):
        cur_track=midi_file[track_num]
        event_total=len(cur_track)
        for event_num in range(event_total):
            cur_event=cur_track[event_num]
            if type(cur_event)==midi.events.NoteOnEvent:
                note_event.append(cur_event)
    return note_event

# %%
def get_note_info(note_event):
    total_info=[]
    for event_idx in range(len(note_event)):
        cur_info=[]
        cur_info.append(note_event[event_idx].get_pitch())
        #cur_info.append(note_event[event_idx].get_velocity())
        total_info.append(np.array(cur_info))
    return np.array(total_info)

# %%
def make_note_data(midi_list):
    X=[]
    for midi_idx in range(len(midi_list)):
        midi_file=midi_list[midi_idx]
        note_event=get_note_event(midi_file)
        note_info=get_note_info(note_event)
        X.append(note_info)
    return np.array(X)

# %%
train_data=make_note_data(midi_list)

# %% [markdown]
# # LSTM

# %%
def normalize(data):
    minx=np.min(data)
    maxx=np.max(data)
    if maxx==minx:
        result=[0 for element in data]
    result=[(element-minx)/(maxx-minx) for element in data]
    result=np.array(result)
    return result,[minx,maxx]

# %%
def make_LSTM_XY(train_data):
    timestep=20
    X=[]
    Y=[]
    tr_info=[]
    for cur_data in train_data:
        total_len=len(cur_data)
        for note_start in range(total_len-timestep):
            pre_note=cur_data[note_start:note_start+timestep+1]
            post_note,tr=normalize(pre_note)
            X.append(np.array(post_note[0:timestep]))
            Y.append(np.array(post_note[timestep]))
            tr_info.append(tr)
    return np.array(X), np.array(Y), np.array(tr_info)

# %%
trainX,trainY,train_tr=make_LSTM_XY(train_data[0:3])
testX,testY,test_tr=make_LSTM_XY(train_data[3:5])
# Out:
# C:\Users\crit9\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: invalid value encountered in true_divide

# %%
from keras.models import Sequential
from keras.layers import GRU, Bidirectional, LSTM, Dropout, Dense

# %%
# Make LSTM network
cell_num=48
dense_num=128
drop_per=0.3

model=Sequential()
model.add(Bidirectional(GRU(cell_num,return_sequences=True),input_shape=(20, 1)))
model.add(Bidirectional(GRU(cell_num)))
model.add(Dropout(drop_per))
model.add(Dense(dense_num,activation='sigmoid'))
model.add(Dense(1,activation='linear'))

# %%
# Training
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=10, batch_size=500, verbose=2, shuffle=False)
# Out:
# Epoch 1/10
# 31s - loss: 0.4410
# Epoch 2/10
# 26s - loss: 0.1225
# Epoch 3/10
# 27s - loss: 0.1132
# Epoch 4/10
# 27s - loss: 0.1095
# Epoch 5/10
# 26s - loss: 0.1079
# Epoch 6/10
# 26s - loss: 0.1071
# Epoch 7/10
# 25s - loss: 0.1049
# Epoch 8/10
# 25s - loss: 0.1018
# Epoch 9/10
# 25s - loss: 0.0962
# Epoch 10/10
# 27s - loss: 0.0926

# %% [markdown]
# # Note prediction

# %%
def translate(pred,info):
    temp_result=[]
    # transform each Y
    for i in range(len(pred)):
        cur_info=info[i]
        cur_pred=pred[i]
        minx=cur_info[0]
        maxx=cur_info[1]
        xrange=maxx-minx
        cur_result=[(p*xrange)+minx for p in cur_pred]
        temp_result.append(np.array(cur_result))
    result=[]
    for i in range(len(temp_result)-1,-1,-1):
        if i==0:
            cur_result=np.flip(temp_result[i],0)
            result.extend(cur_result)
        else:
            result.append(temp_result[i][-1])
    result=np.array(result)
    return np.flip(result,0)

# %%
pred_t=model.predict(trainX)
pred_v=model.predict(testX)
pred_train=translate(pred_t,train_tr)
pred_test=translate(pred_v,test_tr)

# %%
train_result=np.round(pred_train)
test_result=np.round(pred_test)

# %%
print (train_result[0])
# Out:
# 78.0

# %%
# make midi file
def make_midi(result):
    tempo=120
    dur=60
    pattern = midi.Pattern()
    track = midi.Track()
    pattern.append(track)
    for pitch in result:
        on = midi.NoteOnEvent(tick=tempo, velocity=dur, data=[int(pitch),dur])
        track.append(on)
    eot = midi.EndOfTrackEvent(tick=1)
    track.append(eot)
    return pattern

# %%
train_midi=make_midi(train_result)
test_midi=make_midi(test_result)
# Out:
# midi.Pattern(format=1, resolution=220, tracks=\
# [midi.Track(\
#   [midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[86, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[87, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[87, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[75, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[74, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[70, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[71, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[72, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[73, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[76, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[77, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[78, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[79, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[85, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[83, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[84, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[82, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[81, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[80, 60]),
# ...
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[51, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[69, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[58, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[67, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[68, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[46, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[46, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[62, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[66, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[61, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[60, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[64, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[63, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[65, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[57, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[51, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[59, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[51, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[51, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[54, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[51, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[55, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[53, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[51, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[51, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[56, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[46, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[52, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[50, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[47, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[48, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[46, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[46, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[49, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[44, 60]),
#    midi.NoteOnEvent(tick=120, channel=0, data=[46, 60]),
#    midi.EndOfTrackEvent(tick=1, data=[])])])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-188-4c08ff97afa5> in <module>()
#       1 train_midi=make_midi(train_result)
# ----> 2 test_midi=make_midi(test_result)
#
# <ipython-input-187-002c4196fc66> in make_midi(result)
#       7     pattern.append(track)
#       8     for pitch in result:
# ----> 9         on = midi.NoteOnEvent(tick=tempo, velocity=dur, data=[int(pitch),dur])
#      10         track.append(on)
#      11     eot = midi.EndOfTrackEvent(tick=1)
#
# ValueError: cannot convert float NaN to integer

# %%
midi.write_midifile("train.mid", train_midi)
midi.write_midifile("test.mid", test_midi)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-189-e59e2d3cf4ba> in <module>()
# ----> 1 midi.write_midifile("train.mid", train_midi)
#       2 midi.write_midifile("test.mid", test_midi)
#
# C:\Users\crit9\Anaconda3\lib\site-packages\midi-0.2.3-py3.6.egg\midi\fileio.py in write_midifile(midifile, pattern)
#     160         midifile = open(midifile, 'wb')
#     161     writer = FileWriter()
# --> 162     return writer.write(midifile, pattern)
#     163
#     164
#
# C:\Users\crit9\Anaconda3\lib\site-packages\midi-0.2.3-py3.6.egg\midi\fileio.py in write(self, midifile, pattern)
#     106
#     107     def write(self, midifile, pattern):
# --> 108         self.write_file_header(midifile, pattern)
#     109         for track in pattern:
#     110             self.write_track(midifile, track)
#
# C:\Users\crit9\Anaconda3\lib\site-packages\midi-0.2.3-py3.6.egg\midi\fileio.py in write_file_header(self, midifile, pattern)
#     113         # First four bytes are MIDI header
#     114         packdata = pack(">LHHH", 6,
# --> 115                         pattern.format,
#     116                         len(pattern),
#     117                         pattern.resolution)
#
# AttributeError: 'NoneType' object has no attribute 'format'
